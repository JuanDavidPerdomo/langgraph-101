# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
VECTOR_STORE_ID = os.getenv('OPENAI_VECTOR_STORE_ID')

# %%
llm = init_chat_model("openai:gpt-4o", temperature=0.5)

# %%
openai_vector_store_ids = [
    VECTOR_STORE_ID
]

# %%
file_search_tool = {
    "type": "file_search",
    "vector_store_ids": openai_vector_store_ids
}

# %%
llm_with_tools = llm.bind_tools([file_search_tool])

# %%
response = llm_with_tools.invoke("Cómo mejoro el rendimiento de mi website")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'id': 'fs_00b08230b4d0045c0069b04e500cbc819eb7657f0fc9c3a839', 'queries': ['Cómo mejoro el rendimiento de mi website'], 'status': 'completed', 'type': 'file_search_call'}, {'type': 'text', 'text': 'Para mejorar el rendimiento de tu website, puedes seguir estas recomendaciones basadas en el documento que has proporcionado:\n\n1. **Optimización de Imágenes**: Asegúrate de que las imágenes estén correctamente dimensionadas y utiliza formatos de próxima generación como WebP para reducir el tiempo de carga.\n\n2. **Eliminar Recursos que Bloquean el Renderizado**: Minimiza los recursos que impiden que la página se cargue rápidamente, como scripts y estilos que no se usan inmediatamente.\n\n3. **Minificar JavaScript y CSS**: Reduce el tamaño de los archivos JavaScript y CSS para acelerar el tiempo de carga.\n\n4. **Habilitar la Compresión de Texto**: Utiliza la compresión Gzip o Brotli para reducir el tamaño de los archivos de texto enviados desde el servidor.\n\n5. **Implementar AMP (Accelerated Mobile Pages)**: Considera usar AMP para crear páginas que carguen casi instantáneamente, mejorando la experiencia del usuario y potencialmente el rendimiento en SEO.\n\n6. **Establecer Presupuestos de Rendimiento**: Define límites en métricas clave que afecten el rendimiento de tu sitio, como el tiempo de interacción y el tamaño de JavaScript.\n\n7. **Uso de Herramientas de Medición**: Utiliza herramientas como Lighthouse, WebPageTest y PageSpeed Insights para auditar y mejorar el rendimiento de tu sitio.\n\nImplementar estas prácticas puede ayudarte a mejorar significativamente la velocidad y el rendimiento de tu sitio web.', 'annotations': [{'file_id': 'file-WFc3CkxNQcbGSLVEJWs22C', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 306}, {'file_id': 'file-WFc3CkxNQcbGSLVEJWs22C', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 486}, {'file_id': 'file-WFc3CkxNQcbGSLVEJWs22C', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 606}, {'file_id': 'file-WFc3CkxNQcbGSLVEJWs22C', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 760}, {'file_id': 'file-WFc3CkxNQcbGSLVEJWs22C', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 962}, {'file_id': 'file-WFc3CkxNQcbGSLVEJWs22C', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 1140}, {'file_id': 'file-WFc3CkxNQcbGSLVEJWs22C', 'filename': 'Mobile_Site_Speed_Playbook.pdf', 'type': 'file_citation', 'file_index': 1303}], 'id': 'msg_00b08230b4d0045c0069b04e51c14c819e89d3d7a3065be35a'}]
